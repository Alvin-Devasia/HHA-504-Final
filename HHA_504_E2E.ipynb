# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvin-Devasia/HHA-504-Final/blob/main/HHA_504_E2E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymysql
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

import pandas as pd
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b69a9c6c-e7eb-4347-83ed-45cf94341b81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b69a9c6c-e7eb-4347-83ed-45cf94341b81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving H1N1_Flu_Vaccines.csv to H1N1_Flu_Vaccines.csv

# %%
MYSQL_HOSTNAME = '52.154.76.162' 
MYSQL_USER = 'dba'
MYSQL_PASSWORD = 'ahi2020'
MYSQL_DATABASE = 'tempdata'

connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
print (engine.table_names())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# []

# %%
csvfile = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/AHI_STATS_507/main/Week_8_ANOVAS/DataSet/diabetic_data.csv')

# %%
csvfile.to_sql('diabetic_data', con=engine, if_exists='append')

# %%
MYSQL_HOSTNAME = '52.154.76.162' 
MYSQL_USER = 'dba'
MYSQL_PASSWORD = 'ahi2020'
MYSQL_DATABASE = 'e2e'

connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
print (engine.table_names())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# []

# %%
csvfile = pd.read_csv('H1N1_Flu_Vaccines.csv')

# %%
csvfile.to_sql('h1n1', con=engine, if_exists='append')

# %% [markdown]
# Trasnfering a copy of dump.sql file to personal computer

# %% [markdown]
# ![Screen Shot 2021-12-17 at 1.47.30 PM.png](data:image/png;base64,...)
